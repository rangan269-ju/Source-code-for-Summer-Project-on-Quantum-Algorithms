# %%
from qiskit import QuantumCircuit
from qiskit_aer import AerSimulator
from qiskit_aer import Aer
from qiskit.visualization import plot_histogram, plot_bloch_multivector
from qiskit.quantum_info import Statevector
import matplotlib.pyplot as plt

qc = QuantumCircuit(2, 2)
qc.h(0)
qc.cx(0, 1)

qc.measure(0,0)
qc.measure(1,1)


print(qc.draw())

backend= AerSimulator()
result= backend.run(qc, shots=4096).result()
counts= result.get_counts()
print(counts)
plot_histogram(counts)
# Out:
#      ┌───┐     ┌─┐
# q_0: ┤ H ├──■──┤M├───
#      └───┘┌─┴─┐└╥┘┌─┐
# q_1: ─────┤ X ├─╫─┤M├
#           └───┘ ║ └╥┘
# c: 2/═══════════╩══╩═
#                 0  1
# {'00': 2002, '11': 2094}

# %%
from qiskit import QuantumCircuit
from qiskit_aer import AerSimulator
from qiskit.visualization import plot_state_city
from qiskit.quantum_info import Statevector
import matplotlib.pyplot as plt

# %matplotlib inline
qc = QuantumCircuit(2)
qc.h(0)
qc.cx(0, 1)

state = Statevector.from_instruction(qc)
print("Statevector:", state)

plot_state_city(state, title="Quantum State Before Measurement")
plt.show()
# Out:
# Statevector: Statevector([0.70710678+0.j, 0.        +0.j, 0.        +0.j,
#              0.70710678+0.j],
#             dims=(2, 2))

# %%
from qiskit import QuantumCircuit
from qiskit.quantum_info import Statevector
from qiskit.visualization import plot_bloch_multivector, plot_state_city, plot_state_hinton, plot_state_qsphere
import matplotlib.pyplot as plt

qc = QuantumCircuit(2)

qc.h(0)

qc.cx(0, 1)

qc.barrier()


state = Statevector.from_instruction(qc)
# %matplotlib inline

print("Statevector before measurement:")
print(state)

plot_state_city(state, title="Quantum Statevector (City plot)")
plt.show()

plot_state_hinton(state, title="Hinton diagram")
plt.show()

plot_bloch_multivector(state, title="Bloch sphere representation")
plt.show()
# Out:
# Statevector before measurement:
# Statevector([0.70710678+0.j, 0.        +0.j, 0.        +0.j,
#              0.70710678+0.j],
#             dims=(2, 2))
